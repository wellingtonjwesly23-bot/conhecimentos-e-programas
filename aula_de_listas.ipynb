# %% [markdown]
# TUPLAS

# %%
mochila = ('machado','camisa','bacon','abacate')#Funciona assim com os dados todos agrupados na string
print(mochila)
# Out:
# ('machado', 'camisa', 'bacon', 'abacate')

# %%
print(mochila[2])#print do elemento 2 - indice 2
print(mochila[0])#print do elemento 1 - indice 1
print(mochila[0:2])#print do elemento 1 e 2 - indice 0 e 1
print(mochila[2:])#print do elementos a partir do indice 2
print(mochila[-1])#print do ultimo indice
# Out:
# bacon
# machado
# ('machado', 'camisa')
# ('bacon', 'abacate')
# abacate

# %%
mochila[2] = 'ovos'# NA TUPLA NAO SUPORTA ATRIBUIÇÃO

# %%
for item in mochila:
    print(f'na minha mochila tem : {item}')

# %%
mochila = ('machado','camisa','bacon','abacate')
upgrade = ('Queijo','Canivete')
mochila_grande = mochila + upgrade

print(mochila)
print(upgrade)
print(mochila_grande)
# Out:
# ('machado', 'camisa', 'bacon', 'abacate')
# ('Queijo', 'Canivete')
# ('machado', 'camisa', 'bacon', 'abacate', 'Queijo', 'Canivete')

# %%
mochila_invertidag = upgrade + mochila
print(mochila_invertidag)
print(mochila_grande)
# Out:
# ('Queijo', 'Canivete', 'machado', 'camisa', 'bacon', 'abacate')
# ('machado', 'camisa', 'bacon', 'abacate', 'Queijo', 'Canivete')

# %% [markdown]
# DESEMPACOTAMENTO DE PARÂMETROS EM FUNÇÕES

# %%
def soma(*num):
  acumulador = 0
  print(f'Tupla: {num}')
  for i in num:
    acumulador += i
  return acumulador

#programa principal
print(f'Resultado: {soma (1,2)}\n')
print(f'Resultado: {soma (1,2,3,4,5,6,7,8,9)}\n')

# %% [markdown]
# LISTAS

# %%
mochila = ('machado', 'camisa', 'bacon', 'abacate') # NAS TUPLAS USA PARENTESES PARA FECHAR A LISTA
print('Tupla: ', mochila)
mochila = ['machado', 'camisa', 'bacon', 'abacate'] # NAS LISTAS USA COLCHETES PARA FECHAR A LISTA
print('Lista: ', mochila)
# Out:
# Tupla:  ('machado', 'camisa', 'bacon', 'abacate')
# Lista:  ['machado', 'camisa', 'bacon', 'abacate']

# %%
mochila[2] = 'laranja' #EXMPLO DE COMO SUBSTITUIR UM ITEM NO MODELO DA LISTA
print('Lista: ',mochila)
# Out:
# Lista:  ['machado', 'camisa', 'laranja', 'abacate']

# %% [markdown]
# MANIPULANDO LISTAS

# %%
mochila.append('ovos')#adiciona no final da lista
print('lista :', mochila)
# Out:
# lista : ['machado', 'camisa', 'laranja', 'abacate', 'ovos']

# %%
mochila.insert(1 , 'canivete')# inseri na posição informada
print('lista :', mochila)
# Out:
# lista : ['machado', 'canivete', 'camisa', 'laranja', 'abacate', 'ovos']

# %%
del mochila[1] #deleta do indice informado
print('lista :', mochila)
# Out:
# lista : ['machado', 'camisa', 'laranja', 'abacate', 'ovos']

# %%
mochila.remove ('ovos')#deleta o dado informado
print('lista :', mochila)
# Out:
# lista : ['machado', 'camisa', 'laranja', 'abacate']

# %% [markdown]
# 3.STRINGS E LISTAS DENTRO DE LISTAS

# %%
mochila = ['Machado','Camisa','Bacon','Abacate']
print(mochila[0])
# Out:
# Machado

# %%
mochila = ['Machado','Camisa','Bacon','Abacate']
print(mochila[0][0])
print(mochila[2][1])
# Out:
# M
# a

# %%
mochila = ['Machado','Camisa','Bacon','Abacate']
for item in mochila:
  for letra in item:
    print(letra, end='')
  print()
# Out:
# Machado
# Camisa
# Bacon
# Abacate

# %%
mochila = ['Machado','Camisa','Bacon','Abacate']
for i in range(0,len(mochila),1):
  for j in range(0,len(mochila[i]),1):
    print(mochila[i][j], end='')
  print()
# Out:
# Machado
# Camisa
# Bacon
# Abacate

# %% [markdown]
# ALGUNS EX

# %%
item = []
mercado = []
for i in range(3):
  item.append(input('Digite o nome do item: '))
  item.append(float(input('Digite o preço do item: ')))
  item.append(int(input('Digite a quantidade do item: ')))
  mercado.append(item[:])
  item.clear()
print(mercado)
# Out:
# Digite o nome do item: cebola
# Digite o preço do item: 0.49
# Digite a quantidade do item: 200
# Digite o nome do item: tomate
# Digite o preço do item: 0.59
# Digite a quantidade do item: 4
# Digite o nome do item: maçã
# Digite o preço do item: 0.50
# Digite a quantidade do item: 1
# [['cebola', 0.49, 200], ['tomate', 0.59, 4], ['maçã', 0.5, 1]]

# %% [markdown]
# DICIONARIOS

# %%
#EXEMPLOS
mochila = ('laptop', 'smartphone' , 'power bank', 'carregador e cabos')
print('tupla:', mochila)

mochila = ['laptop', 'smartphone' , 'power bank', 'carregador e cabos']
print('lista:', mochila)

mochila = {'laptop':1, 'smartphone':2 , 'power bank':3, 'carregador e cabos':4}
print('dicionario:', mochila)
# Out:
# tupla: ('laptop', 'smartphone', 'power bank', 'carregador e cabos')
# lista: ['laptop', 'smartphone', 'power bank', 'carregador e cabos']
# dicionario: {'laptop': 1, 'smartphone': 2, 'power bank': 3, 'carregador e cabos': 4}

# %%
game = {'nome': 'god of war', 'ano':2008,
        'desenvolvedora':'santa monica'}
print(game)
# Out:
# {'nome': 'god of war', 'ano': 2008, 'desenvolvedora': 'santa monica'}

# %%
print(game['nome'])
print(game['ano'])
print(game['desenvolvedora'])
# Out:
# god of war
# 2008
# santa monica

# %%
print(game.keys())
print(game.values())
print(game.items)
# Out:
# dict_keys(['nome', 'ano', 'desenvolvedora'])
# dict_values(['god of war', 2008, 'santa monica'])
# <built-in method items of dict object at 0x789ab9172080>

# %%
for keys in game.keys():
  print(keys)
# Out:
# nome
# ano
# desenvolvedora

# %%
for keys, values in game.items():
  print(f'{keys} = {values}')
# Out:
# nome = god of war
# ano = 2008
# desenvolvedora = santa monica

# %% [markdown]
# LISTAS COM DICIONARIOS

# %%
games = []
game1 = {'nome':'super mario',
          'ano':1996 ,
          'desenvolvedora':'nintendo'}
game2 = {'nome':'god of war',
          'ano': 2008 ,
         'desenvolvedora':'santa monica'}
game3 = {'nome':'mario bros',
          'ano': 1990,
         'desenvolvedora':'nintendo'}
games = [game1 , game2 , game3]
print(games)
# Out:
# [{'nome': 'super mario', 'ano': 1996, 'desenvolvedora': 'nintendo'}, {'nome': 'god of war', 'ano': 2008, 'desenvolvedora': 'santa monica'}, {'nome': 'mario bros', 'ano': 1990, 'desenvolvedora': 'nintendo'}]

# %%
game = {}
games = []

for i in range(3):
  game['nome'] = input('Digite o nome do jogo: ')
  game['ano'] = int(input('Digite o ano do jogo: '))
  game['desenvolvedora'] = input('Digite a desenvolvedora do jogo: ')
  games.append(game.copy())
print('-' * 20)
for jogos in games:
  for keys, values in jogos.items():
    print(f'o campo tem: {keys} tem o valor {values}.')
# Out:
# Digite o nome do jogo: zelda
# Digite o ano do jogo: 1990
# Digite a desenvolvedora do jogo: nintendo
# Digite o nome do jogo: god of war
# Digite o ano do jogo: 2008
# Digite a desenvolvedora do jogo: santa monica
# Digite o nome do jogo: super mario
# Digite o ano do jogo: 1995
# Digite a desenvolvedora do jogo: nintendo
# --------------------
# o campo tem: nome tem o valor zelda.
# o campo tem: ano tem o valor 1990.
# o campo tem: desenvolvedora tem o valor nintendo.
# o campo tem: nome tem o valor god of war.
# o campo tem: ano tem o valor 2008.
# o campo tem: desenvolvedora tem o valor santa monica.
# o campo tem: nome tem o valor super mario.
# o campo tem: ano tem o valor 1995.
# o campo tem: desenvolvedora tem o valor nintendo.
